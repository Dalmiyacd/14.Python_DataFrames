# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series

# %%
import webbrowser
website ='https://pandas.pydata.org/pandas-docs/dev/reference/api/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('xGbpuFNR1ME')

# %% [markdown]
# ## Creating a DataFrame ##

# %% [markdown]
# #### a. Read from clipboard ####

# %%
#nfl = pd.read_clipboard(
#nfl

# %%
#nfl.to_csv('nfl.csv')

# %% [markdown]
# #### a. Read from csv files ####

# %%
nfl_bkp = pd.read_csv('nfl.csv')
nfl_bkp
# Out:
#    Unnamed: 0       Rank     Team        GP    Won  Lost  Tied    Pct.  \
# 0           1      Green      Bay   Packers  1,384   769   577  38.000
# 1           2     Dallas  Cowboys       930    526   398     6   0.569
# 2           3  Baltimore   Ravens       400    225   174     1   0.564
# 3           4    Chicago    Bears     1,418    777   599    42   0.563
# 4           5        New  England  Patriots    932   519   404   9.000
#
#       First   NFL season Division
# 0     0.569  1921    NFC    North
# 1  1960.000   NFC   East      NaN
# 2  1996.000   AFC  North      NaN
# 3  1920.000   NFC  North      NaN
# 4     0.562  1960    AFC     East

# %%
type(nfl_bkp)
# Out:
# pandas.core.frame.DataFrame

# %%
# to find the columns

# %%
nfl_bkp.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.',
#        'First', 'NFL', 'season', 'Division'],
#       dtype='object')

# %%
nfl = nfl_bkp
nfl
# Out:
#    Unnamed: 0       Rank     Team        GP    Won  Lost  Tied    Pct.  \
# 0           1      Green      Bay   Packers  1,384   769   577  38.000
# 1           2     Dallas  Cowboys       930    526   398     6   0.569
# 2           3  Baltimore   Ravens       400    225   174     1   0.564
# 3           4    Chicago    Bears     1,418    777   599    42   0.563
# 4           5        New  England  Patriots    932   519   404   9.000
#
#       First   NFL season Division
# 0     0.569  1921    NFC    North
# 1  1960.000   NFC   East      NaN
# 2  1996.000   AFC  North      NaN
# 3  1920.000   NFC  North      NaN
# 4     0.562  1960    AFC     East

# %%
ex = pd.read_csv('universities.csv')
ex
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
# if we dnt need header

# %%
ex = pd.read_csv('universities.csv',header = None)
ex.head()
# Out:
#           0     1      2       3        4         5         6
# 0      Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 1     Brown  1310     89      22       13     22704        94
# 2   CalTech  1415    100      25        6     63575        81
# 3       CMU  1260     62      59        9     25026        72
# 4  Columbia  1310     76      24       12     31510        88

# %%
# if we need header

# %%
ex = pd.read_csv('universities.csv')
ex.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
# To read only few rows from the dataset

# %%
pd.read_csv('universities.csv', nrows=2)
# Out:
#       Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0    Brown  1310     89      22       13     22704        94
# 1  CalTech  1415    100      25        6     63575        81

# %%
# To read only few columns from the dataset

# %%
d=pd.read_csv('universities.csv', usecols=[1,2])
d
d.head()
# Out:
#     SAT  Top10
# 0  1310     89
# 1  1415    100
# 2  1260     62
# 3  1310     76
# 4  1280     83

# %% [markdown]
# #### c. Create from a numpy array

# %%
arr = np.array([[1,2,3],[4,5,6]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
df = DataFrame(arr, index=[1,2],columns=['c1','c2','c3'])
df
# Out:
#    c1  c2  c3
# 1   1   2   3
# 2   4   5   6

# %%
dframe1 = DataFrame(np.arange(9).reshape((3,3)), index = ['SF', 'LA','NY'], columns = ['pop','size','year'])
dframe1
# Out:
#     pop  size  year
# SF    0     1     2
# LA    3     4     5
# NY    6     7     8

# %% [markdown]
# ##### d. From dictionaries

# %%
dict_frame = DataFrame({'col1':[1,2,3],'col2':[11,12,13]})
dict_frame
# Out:
#    col1  col2
# 0     1    11
# 1     2    12
# 2     3    13

# %% [markdown]
# ### Selecting Data

# %%
# To Select columns

# %%
nfl.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.',
#        'First', 'NFL', 'season', 'Division'],
#       dtype='object')

# %%
# To choose a particular columns

# %%
nfl.Team
# Out:
# 0        Bay
# 1    Cowboys
# 2     Ravens
# 3      Bears
# 4    England
# Name: Team, dtype: object

# %%
nfl['season']
# Out:
# 0      NFC
# 1     East
# 2    North
# 3    North
# 4      AFC
# Name: season, dtype: object

# %%
# to choose multiple column

# %%
nfl[['Team','Rank']]
# Out:
#       Team       Rank
# 0      Bay      Green
# 1  Cowboys     Dallas
# 2   Ravens  Baltimore
# 3    Bears    Chicago
# 4  England        New

# %%
## Throws an error for non-existent columns
#nfl[['Team','Rank','Stadium']]

# %%
## Another way
## Note columns can be any collection
DataFrame(nfl, columns=['Team','Rank','Stadium'])
# Out:
#       Team       Rank  Stadium
# 0      Bay      Green      NaN
# 1  Cowboys     Dallas      NaN
# 2   Ravens  Baltimore      NaN
# 3    Bears    Chicago      NaN
# 4  England        New      NaN

# %%
nfl
# Out:
#    Unnamed: 0       Rank     Team        GP    Won  Lost  Tied    Pct.  \
# 0           1      Green      Bay   Packers  1,384   769   577  38.000
# 1           2     Dallas  Cowboys       930    526   398     6   0.569
# 2           3  Baltimore   Ravens       400    225   174     1   0.564
# 3           4    Chicago    Bears     1,418    777   599    42   0.563
# 4           5        New  England  Patriots    932   519   404   9.000
#
#       First   NFL season Division
# 0     0.569  1921    NFC    North
# 1  1960.000   NFC   East      NaN
# 2  1996.000   AFC  North      NaN
# 3  1920.000   NFC  North      NaN
# 4     0.562  1960    AFC     East

# %%
#Select value from nfl dataframe

# %%
nfl['Tied'] > 100
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Tied, dtype: bool

# %%
# to get the description of the true value

# %%
nfl[nfl['Tied'] > 100]
# Out:
#    Unnamed: 0   Rank     Team        GP    Won  Lost  Tied  Pct.  First   NFL  \
# 0           1  Green      Bay   Packers  1,384   769   577  38.0  0.569  1921
# 4           5    New  England  Patriots    932   519   404   9.0  0.562  1960
#
#   season Division
# 0    NFC    North
# 4    AFC     East

# %%
#head method

# %%
nfl.head(3)
# Out:
#    Unnamed: 0       Rank     Team       GP    Won  Lost  Tied    Pct.  \
# 0           1      Green      Bay  Packers  1,384   769   577  38.000
# 1           2     Dallas  Cowboys      930    526   398     6   0.569
# 2           3  Baltimore   Ravens      400    225   174     1   0.564
#
#       First   NFL season Division
# 0     0.569  1921    NFC    North
# 1  1960.000   NFC   East      NaN
# 2  1996.000   AFC  North      NaN

# %%
#Tail method

# %%
nfl.tail(3)
# Out:
#    Unnamed: 0       Rank     Team        GP  Won  Lost  Tied   Pct.     First  \
# 2           3  Baltimore   Ravens       400  225   174     1  0.564  1996.000
# 3           4    Chicago    Bears     1,418  777   599    42  0.563  1920.000
# 4           5        New  England  Patriots  932   519   404  9.000     0.562
#
#     NFL season Division
# 2   AFC  North      NaN
# 3   NFC  North      NaN
# 4  1960    AFC     East

# %%
#Add new columns

# %%
nfl['Stadium'] = 'Nokia Stadium'
nfl
# Out:
#    Unnamed: 0       Rank     Team        GP    Won  Lost  Tied    Pct.  \
# 0           1      Green      Bay   Packers  1,384   769   577  38.000
# 1           2     Dallas  Cowboys       930    526   398     6   0.569
# 2           3  Baltimore   Ravens       400    225   174     1   0.564
# 3           4    Chicago    Bears     1,418    777   599    42   0.563
# 4           5        New  England  Patriots    932   519   404   9.000
#
#       First   NFL season Division        Stadium
# 0     0.569  1921    NFC    North  Nokia Stadium
# 1  1960.000   NFC   East      NaN  Nokia Stadium
# 2  1996.000   AFC  North      NaN  Nokia Stadium
# 3  1920.000   NFC  North      NaN  Nokia Stadium
# 4     0.562  1960    AFC     East  Nokia Stadium

# %% [markdown]
# ## Index Objects

# %%
from numpy.random import randn

# %%
nfl.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
from numpy.random import randn

# %%
nfl
# Out:
#    Unnamed: 0       Rank     Team        GP    Won  Lost  Tied    Pct.  \
# 0           1      Green      Bay   Packers  1,384   769   577  38.000
# 1           2     Dallas  Cowboys       930    526   398     6   0.569
# 2           3  Baltimore   Ravens       400    225   174     1   0.564
# 3           4    Chicago    Bears     1,418    777   599    42   0.563
# 4           5        New  England  Patriots    932   519   404   9.000
#
#       First   NFL season Division        Stadium
# 0     0.569  1921    NFC    North  Nokia Stadium
# 1  1960.000   NFC   East      NaN  Nokia Stadium
# 2  1996.000   AFC  North      NaN  Nokia Stadium
# 3  1920.000   NFC  North      NaN  Nokia Stadium
# 4     0.562  1960    AFC     East  Nokia Stadium

# %%
new_index = [10,20,40,50,60]
nfl2 = nfl.reindex(new_index)
nfl2
# Out:
#     Unnamed: 0 Rank Team   GP  Won  Lost  Tied  Pct.  First  NFL season  \
# 10         NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN  NaN    NaN
# 20         NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN  NaN    NaN
# 40         NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN  NaN    NaN
# 50         NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN  NaN    NaN
# 60         NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN    NaN  NaN    NaN
#
#    Division Stadium
# 10      NaN     NaN
# 20      NaN     NaN
# 40      NaN     NaN
# 50      NaN     NaN
# 60      NaN     NaN

# %% [markdown]
# #### Dropping a row or a column

# %%
dframe1 = DataFrame(np.arange(9).reshape((3,3)),index=['SF','LA','NY'],columns=['pop','size','year'])

#Show (remember just random values)
dframe1
# Out:
#     pop  size  year
# SF    0     1     2
# LA    3     4     5
# NY    6     7     8

# %%
dframe1.drop('LA')
# Out:
#     pop  size  year
# SF    0     1     2
# NY    6     7     8

# %%
dframe1.drop('year', axis=1)
#axis=1 refer to column and axis=0 refer to row
# Out:
#     pop  size
# SF    0     1
# LA    3     4
# NY    6     7

# %% [markdown]
# ### Adding within the data set

# %%
arr = np.array([[1,2,3],[4,15,1],[11,12,13]])

# %%
    df = DataFrame(arr,index=[1,2,3], columns =['c1','c2','c3'])
    df
# Out:
#    c1  c2  c3
# 1   1   2   3
# 2   4  15   1
# 3  11  12  13

# %%
## Ignores NaN values
df.sum()
# Out:
# c1    16
# c2    29
# c3    17
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 1     6
# 2    20
# 3    36
# dtype: int64

# %%
#Can also get min and max values of dataframe
df.min()
# Out:
# c1    1
# c2    2
# c3    1
# dtype: int32

# %%
df.min(axis=1)
# Out:
# 1     1
# 2     1
# 3    11
# dtype: int32

# %%
df.max()
# Out:
# c1    11
# c2    15
# c3    13
# dtype: int32

# %%
df.max(axis=1)
# Out:
# 1     3
# 2    15
# 3    13
# dtype: int32

# %%
## Index position of the minimum and maximum values
df.idxmin()
# Out:
# c1    1
# c2    1
# c3    2
# dtype: int64

# %%
df.idxmin(axis=1)
# Out:
# 1    c1
# 2    c3
# 3    c1
# dtype: object

# %%
df.idxmax()
# Out:
# c1    3
# c2    2
# c3    3
# dtype: int64

# %%
df.idxmax(axis=1)
# Out:
# 1    c3
# 2    c2
# 3    c3
# dtype: object

# %%
## Cumulative sum
df.cumsum()
# Out:
#    c1  c2  c3
# 1   1   2   3
# 2   5  17   4
# 3  16  29  17

# %% [markdown]
# ### Summary Statistics

# %%
df
# Out:
#    c1  c2  c3
# 1   1   2   3
# 2   4  15   1
# 3  11  12  13

# %%
df.describe()
# Out:
#               c1         c2         c3
# count   3.000000   3.000000   3.000000
# mean    5.333333   9.666667   5.666667
# std     5.131601   6.806859   6.429101
# min     1.000000   2.000000   1.000000
# 25%     2.500000   7.000000   2.000000
# 50%     4.000000  12.000000   3.000000
# 75%     7.500000  13.500000   8.000000
# max    11.000000  15.000000  13.000000

# %% [markdown]
# ### Missing Data

# %%
dframe = DataFrame([[1,2,3],[np.nan,5,6],[7,np.nan,9],[np.nan,np.nan,np.nan]])
dframe
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0
# 3  NaN  NaN  NaN

# %%
new_dframe = dframe.dropna()
new_dframe
# Out:
#      0    1    2
# 0  1.0  2.0  3.0

# %%
#We can also specify to only drop rows that are complete missing all data
dframe.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  5.0  6.0
# 2  7.0  NaN  9.0

# %%
#Or we can specify to drop columns with missing data
dframe = DataFrame([[1,2,3,4],[np.nan,5,6,11],[7,np.nan,9,10],[np.nan,np.nan,np.nan,33]])
dframe
# Out:
#      0    1    2   3
# 0  1.0  2.0  3.0   4
# 1  NaN  5.0  6.0  11
# 2  7.0  NaN  9.0  10
# 3  NaN  NaN  NaN  33

# %%
dframe.dropna(axis=1)
# Out:
#     3
# 0   4
# 1  11
# 2  10
# 3  33

# %%
#Dropping any rows that dont have at least 2 data points
dframe.dropna(thresh=2)
# Out:
#      0    1    2   3
# 0  1.0  2.0  3.0   4
# 1  NaN  5.0  6.0  11
# 2  7.0  NaN  9.0  10

# %%
#We can also fill any NAN
dframe.fillna(1)
# Out:
#      0    1    2   3
# 0  1.0  2.0  3.0   4
# 1  1.0  5.0  6.0  11
# 2  7.0  1.0  9.0  10
# 3  1.0  1.0  1.0  33

# %%
#Can also fill in diff values for diff columns
dframe.fillna({0:10,1:100,2:200,3:300})
# Out:
#       0      1      2   3
# 0   1.0    2.0    3.0   4
# 1  10.0    5.0    6.0  11
# 2   7.0  100.0    9.0  10
# 3  10.0  100.0  200.0  33

# %%
#Can also fill in diff values for diff columns
dframe.fillna({1:300})
# Out:
#      0      1    2   3
# 0  1.0    2.0  3.0   4
# 1  NaN    5.0  6.0  11
# 2  7.0  300.0  9.0  10
# 3  NaN  300.0  NaN  33

# %%
#If we want to modify the exsisting object, use inplace
dframe.fillna(0,inplace=True)
dframe
# Out:
#      0    1    2   3
# 0  1.0  2.0  3.0   4
# 1  0.0  5.0  6.0  11
# 2  7.0  0.0  9.0  10
# 3  0.0  0.0  0.0  33

# %% [markdown]
# ### Merge data

# %%
dmerge1 = DataFrame({'key':['X','Z','Y','Z','X','X'],'col_1': np.arange(6),'key2':['a','b','b','c','a','c']})
dmerge1
# Out:
#   key  col_1 key2
# 0   X      0    a
# 1   Z      1    b
# 2   Y      2    b
# 3   Z      3    c
# 4   X      4    a
# 5   X      5    c

# %%
dmerge2 = DataFrame({'key':['Q','Y','Z'],'col_2':[1,2,3],'key2':['a','c','c']})
dmerge2
# Out:
#   key  col_2 key2
# 0   Q      1    a
# 1   Y      2    c
# 2   Z      3    c

# %%
pd.merge(dmerge1,dmerge2, on='key')
# Out:
#   key  col_1 key2_x  col_2 key2_y
# 0   Z      1      b      3      c
# 1   Z      3      c      3      c
# 2   Y      2      b      2      c

# %%
pd.merge(dmerge1,dmerge2, on='key', how='left')
# Out:
#   key  col_1 key2_x  col_2 key2_y
# 0   X      0      a    NaN    NaN
# 1   Z      1      b    3.0      c
# 2   Y      2      b    2.0      c
# 3   Z      3      c    3.0      c
# 4   X      4      a    NaN    NaN
# 5   X      5      c    NaN    NaN

# %%
pd.merge(dmerge2,dmerge1, on='key', how='left')
# Out:
#   key  col_2 key2_x  col_1 key2_y
# 0   Q      1      a    NaN    NaN
# 1   Y      2      c    2.0      b
# 2   Z      3      c    1.0      b
# 3   Z      3      c    3.0      c

# %%
pd.merge(dmerge2,dmerge1, on='key', how='right')
# Out:
#   key  col_2 key2_x  col_1 key2_y
# 0   X    NaN    NaN      0      a
# 1   Z    3.0      c      1      b
# 2   Y    2.0      c      2      b
# 3   Z    3.0      c      3      c
# 4   X    NaN    NaN      4      a
# 5   X    NaN    NaN      5      c

# %%
pd.merge(dmerge1,dmerge2, on='key', how='right')
# Out:
#   key  col_1 key2_x  col_2 key2_y
# 0   Q    NaN    NaN      1      a
# 1   Y    2.0      b      2      c
# 2   Z    1.0      b      3      c
# 3   Z    3.0      c      3      c

# %%
#outer Ring Joint

# %% [markdown]
# pd.merge(dmerge1,dmerge2, on='key', how='outer', sort=True)

# %%
dframe1 = DataFrame(np.random.randn(4,3), columns=['X', 'Y', 'Z'])
dframe1
# Out:
#           X         Y         Z
# 0  0.488541  1.197425  0.099139
# 1  0.265504 -0.943358  0.559462
# 2  0.120310 -0.630254  0.216667
# 3  0.814358 -1.874662 -0.883850

# %%
dframe2 = DataFrame(np.random.randn(3, 3), columns=['Y', 'Q', 'X'])
dframe2
# Out:
#           Y         Q         X
# 0 -2.372334  1.913897  0.186792
# 1  1.156049  1.171746  0.020703
# 2 -1.753418  0.634422 -0.149069

# %%
pd.concat([dframe1,dframe2])
# Out:
#           X         Y         Z         Q
# 0  0.488541  1.197425  0.099139       NaN
# 1  0.265504 -0.943358  0.559462       NaN
# 2  0.120310 -0.630254  0.216667       NaN
# 3  0.814358 -1.874662 -0.883850       NaN
# 0  0.186792 -2.372334       NaN  1.913897
# 1  0.020703  1.156049       NaN  1.171746
# 2 -0.149069 -1.753418       NaN  0.634422

# %%
pd.concat([dframe1,dframe2],ignore_index=True)
# Out:
#           X         Y         Z         Q
# 0  0.488541  1.197425  0.099139       NaN
# 1  0.265504 -0.943358  0.559462       NaN
# 2  0.120310 -0.630254  0.216667       NaN
# 3  0.814358 -1.874662 -0.883850       NaN
# 4  0.186792 -2.372334       NaN  1.913897
# 5  0.020703  1.156049       NaN  1.171746
# 6 -0.149069 -1.753418       NaN  0.634422

# %%
dframe1
# Out:
#           X         Y         Z
# 0  0.488541  1.197425  0.099139
# 1  0.265504 -0.943358  0.559462
# 2  0.120310 -0.630254  0.216667
# 3  0.814358 -1.874662 -0.883850

# %%
dframe2
# Out:
#           Y         Q         X
# 0 -2.372334  1.913897  0.186792
# 1  1.156049  1.171746  0.020703
# 2 -1.753418  0.634422 -0.149069

# %%
pd.concat([dframe1,dframe2],ignore_index=True, axis=1)
# Out:
#           0         1         2         3         4         5
# 0  0.488541  1.197425  0.099139 -2.372334  1.913897  0.186792
# 1  0.265504 -0.943358  0.559462  1.156049  1.171746  0.020703
# 2  0.120310 -0.630254  0.216667 -1.753418  0.634422 -0.149069
# 3  0.814358 -1.874662 -0.883850       NaN       NaN       NaN

# %%
#dpiv = pd.read_csv('pivot.csv').drop('Unnamed: 0', axis=1)
#dpiv

# %%
#dpiv.pivot('date','variable','value')

# %% [markdown]
# ### Handling Duplicates

# %%
ddup = DataFrame({'col1':['A','A','B','B','B'], 'col2':[2,2,2,3,3]})
ddup
# Out:
#   col1  col2
# 0    A     2
# 1    A     2
# 2    B     2
# 3    B     3
# 4    B     3

# %%
#Use duplicated to find duplicates
ddup.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
#Drop only the duplicate
ddup.drop_duplicates()
# Out:
#   col1  col2
# 0    A     2
# 2    B     2
# 3    B     3

# %%
ddup.drop_duplicates(keep='last')
# Out:
#   col1  col2
# 1    A     2
# 2    B     2
# 4    B     3

# %%
ddup
# Out:
#   col1  col2
# 0    A     2
# 1    A     2
# 2    B     2
# 3    B     3
# 4    B     3

# %%
## You can filter which duplicates to drop by a single column
## ddup.drop_duplicates(['col1'])
ddup.drop_duplicates(subset=['col1'])
# Out:
#   col1  col2
# 0    A     2
# 2    B     2

# %%
 ddup.drop_duplicates(['col1'])
# Out:
#   col1  col2
# 0    A     2
# 2    B     2

# %% [markdown]
# ### Mapping

# %%
## Mapping
dmap = DataFrame({'state':['Kerala','Tamilnadu','Karnataka','Telangana'],'population':[1000,2500,2700,1300]})
dmap
# Out:
#        state  population
# 0     Kerala        1000
# 1  Tamilnadu        2500
# 2  Karnataka        2700
# 3  Telangana        1300

# %%
capitals ={'Tamilnadu':'Chennai','Karnataka':'Bangalore','Kerala':'Trivandrum','Telangana':'Hyderabad'}
capitals
# Out:
# {'Tamilnadu': 'Chennai',
#  'Karnataka': 'Bangalore',
#  'Kerala': 'Trivandrum',
#  'Telangana': 'Hyderabad'}

# %%
dmap['capital'] = dmap['state'].map(capitals)
dmap
# Out:
#        state  population     capital
# 0     Kerala        1000  Trivandrum
# 1  Tamilnadu        2500     Chennai
# 2  Karnataka        2700   Bangalore
# 3  Telangana        1300   Hyderabad

# %% [markdown]
# ## Group By

# %%
dgrp = pd.read_csv('nba.csv')
dgrp
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
grp = dgrp.groupby('Team')

# %%
for team,group in grp:
    print(team,group[['Name','Position','Age']])
# Out:
# Atlanta Hawks                  Name Position   Age
# 309     Kent Bazemore       SF  26.0
# 310  Tim Hardaway Jr.       SG  24.0
# 311      Kirk Hinrich       SG  35.0
# 312        Al Horford        C  30.0
# 313    Kris Humphries       PF  31.0
# 314       Kyle Korver       SG  35.0
# 315      Paul Millsap       PF  31.0
# 316      Mike Muscala       PF  24.0
# 317   Lamar Patterson       SG  24.0
# 318   Dennis Schroder       PG  22.0
# 319        Mike Scott       PF  27.0
# 320   Thabo Sefolosha       SF  32.0
# 321    Tiago Splitter        C  31.0
# 322    Walter Tavares        C  24.0
# 323       Jeff Teague       PG  27.0
# Boston Celtics                Name Position   Age
# 0     Avery Bradley       PG  25.0
# 1       Jae Crowder       SF  25.0
# 2      John Holland       SG  27.0
# 3       R.J. Hunter       SG  22.0
# 4     Jonas Jerebko       PF  29.0
# 5      Amir Johnson       PF  29.0
# 6     Jordan Mickey       PF  21.0
# 7      Kelly Olynyk        C  25.0
# ...

# %%
grp.get_group('Atlanta Hawks')
# Out:
#                  Name           Team  Number Position   Age Height  Weight  \
# 309     Kent Bazemore  Atlanta Hawks    24.0       SF  26.0    6-5   201.0
# 310  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 311      Kirk Hinrich  Atlanta Hawks    12.0       SG  35.0    6-4   190.0
# 312        Al Horford  Atlanta Hawks    15.0        C  30.0   6-10   245.0
# 313    Kris Humphries  Atlanta Hawks    43.0       PF  31.0    6-9   235.0
# 314       Kyle Korver  Atlanta Hawks    26.0       SG  35.0    6-7   212.0
# 315      Paul Millsap  Atlanta Hawks     4.0       PF  31.0    6-8   246.0
# 316      Mike Muscala  Atlanta Hawks    31.0       PF  24.0   6-11   240.0
# 317   Lamar Patterson  Atlanta Hawks    13.0       SG  24.0    6-5   225.0
# 318   Dennis Schroder  Atlanta Hawks    17.0       PG  22.0    6-1   172.0
# 319        Mike Scott  Atlanta Hawks    32.0       PF  27.0    6-8   237.0
# ...

# %%
grp2 = dgrp.groupby(['Team','Position'])

# %%
for team, group in grp2:
    print(team, group)
# Out:
# ('Atlanta Hawks', 'C')                Name           Team  Number Position   Age Height  Weight  \
# 312      Al Horford  Atlanta Hawks    15.0        C  30.0   6-10   245.0
# 321  Tiago Splitter  Atlanta Hawks    11.0        C  31.0   6-11   245.0
# 322  Walter Tavares  Atlanta Hawks    22.0        C  24.0    7-3   260.0
#
#      College      Salary
# 312  Florida  12000000.0
# 321      NaN   9756250.0
# 322      NaN   1000000.0
# ('Atlanta Hawks', 'PF')                Name           Team  Number Position   Age Height  Weight  \
# 313  Kris Humphries  Atlanta Hawks    43.0       PF  31.0    6-9   235.0
# 315    Paul Millsap  Atlanta Hawks     4.0       PF  31.0    6-8   246.0
# 316    Mike Muscala  Atlanta Hawks    31.0       PF  24.0   6-11   240.0
# 319      Mike Scott  Atlanta Hawks    32.0       PF  27.0    6-8   237.0
#
#             College      Salary
# 313       Minnesota   1000000.0
# 315  Louisiana Tech  18671659.0
# 316        Bucknell    947276.0
# ...

# %%
grp2.get_group(('Atlanta Hawks','PG'))
# Out:
#                 Name           Team  Number Position   Age Height  Weight  \
# 318  Dennis Schroder  Atlanta Hawks    17.0       PG  22.0    6-1   172.0
# 323      Jeff Teague  Atlanta Hawks     0.0       PG  27.0    6-2   186.0
#
#          College     Salary
# 318          NaN  1763400.0
# 323  Wake Forest  8000000.0

# %% [markdown]
# ### Rename columns of a DataFrame

# %%
dmap
# Out:
#        state  population     capital
# 0     Kerala        1000  Trivandrum
# 1  Tamilnadu        2500     Chennai
# 2  Karnataka        2700   Bangalore
# 3  Telangana        1300   Hyderabad

# %%
dmap.rename(columns = {'state':'province'},inplace=True)
dmap
# Out:
#     province  population     capital
# 0     Kerala        1000  Trivandrum
# 1  Tamilnadu        2500     Chennai
# 2  Karnataka        2700   Bangalore
# 3  Telangana        1300   Hyderabad

# %%
dmap.rename(columns = {'province':'state','population':'pops'},inplace=True)
dmap
# Out:
#        state  pops     capital
# 0     Kerala  1000  Trivandrum
# 1  Tamilnadu  2500     Chennai
# 2  Karnataka  2700   Bangalore
# 3  Telangana  1300   Hyderabad
